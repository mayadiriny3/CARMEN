# %% [markdown]
# <img src="https://drive.google.com/uc?id=1k-sN5F0Dtb3qVQhmNWBQcyFHDwEwmDZ1" alt="" width="400" >

# %% [markdown]
# # **Problemario**
#
# Nombre del alumno:
# * MORENO GONZALEZ MARIA DEL CARMEN
#
# Matricula:
# * 21011643
#
# Asignatura: Matemáticas Aplicadas a la Comunicaciones
#
# Fecha de entrega: 20-10-2022
#
# Tema: **Transformada de Laplace**
#
# Temas:
#
#
# * 2.1 Definición y propiedades de la transformada de Laplace
# * 2.2 Condiciones suficientes de existencia para la transformada de Laplace
# * 2.3 Tranformada de Laplace
# * 2.4 Transformada inversa
# * 2.5 Transformada de derivadas (Teorema)
# * 2.6 Tranformada de diferenciales (Teorema)
# * 2.7 Teorema de consolación
# * 2.8 Transformada de Laplace de una función periodica
# * 2.9 Solución de ecuación diferenciales

# %% [markdown]
# ### **Librerias utilizadas**

# %%
# Importar librerias basicas
import sympy
import math

# imprimir con notación matemática.
sympy.init_printing(use_latex='mathjax')

print("Bibliotecas cargadas")
# Out:
# Bibliotecas cargadas

# %% [markdown]
# # Tabla de contenidos
#
# * [Sección I](#Sección-I:)
#     * [Transformada de Laplace](#Transformada-de-Laplace)
#     * [Inversa de la Transformada de Laplace](#Inversa-de-la-Transformada-de-Laplace)
#     * [Transformada de Laplace Derivada](#Transformada-de-Laplace-Derivada)
#
#
#
# * [Sección II](#Sección-2:)
#     * [Problemario](#Problemario.)
#
#
#
# * [Referencias](#Referencias)

# %% [markdown]
# # Sección I:
#
# ##### [[Tabla de contenidos]](#Tabla-de-contenidos) [[Sección II]](#Sección-2:)
#
# **Instrucciones**
#
# Presenta los problemas y/o ejercicios resueltos en clase:

# %% [markdown]
# # **Firma de revision**

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1KDJro5T8ZWwny5nYB8yWOV74AhRIJ1cX" alt="" width="400" >

# %% [markdown]
# ### Transformada de Laplace
# ##### [[Tabla de contenidos]](#Tabla-de-contenidos) [[Sección II]](#Sección-2:)

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1KQh4J71-ipl2ZFYtyorntwDLZQcQ8XBi" alt="" width="400" >

# %%
t, s = sympy.symbols('t, s')
a = sympy.symbols('a', real=True, positive=True)

f = 1
f
# Out:
# 1

# %%
F = sympy.laplace_transform(f, t, s, noconds=True)
F
# Out:
# 1
# ─
# s

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1K_TkHuImK_WiJ_4cf31YGnXWm1bXJLjG" alt="" width="400" >

# %%
t, s = sympy.symbols('t, s')
a = sympy.symbols('a', real=True, positive=True)

f = 2
f
# Out:
# 2

# %%
F = sympy.laplace_transform(f, t, s, noconds=True)
F
# Out:
# 2
# ─
# s

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1KdJluzmae4clT3HXpU3SDEwFTavujijc" alt="" width="400" >

# %%
t, s = sympy.symbols('t, s')
a = sympy.symbols('a', real=True, positive=True)

f = 3
f
# Out:
# 3

# %%
F = sympy.laplace_transform(f, t, s, noconds=True)
F
# Out:
# 3
# ─
# s

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1KwLnlYS9GIN0PWHq1MfbmX9D_aUQAT4T" alt="" width="400" >

# %%
t, s = sympy.symbols('t, s')
a = sympy.symbols('a', real=True, positive=True)

f = 4
f
# Out:
# 4

# %%
F = sympy.laplace_transform(f, t, s, noconds=True)
F
# Out:
# 4
# ─
# s

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1Kf4Y7B0XQsbSC7RTXAcqr1vD_gy2Mnne" alt="" width="400" >

# %%
t, s = sympy.symbols('t, s')
a = sympy.symbols('a', real=True, positive=True)

f = t
f
# Out:
# t

# %%
F = sympy.laplace_transform(f, t, s, noconds=True)
F
# Out:
# 1
# ──
#  2
# s

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1LeD4hcBIhC2PQwo6hQpLdv-F9xSbeEQJ" alt="" width="400" >

# %%
t, s = sympy.symbols('t, s')
a = sympy.symbols('a', real=True, positive=True)

f = t**2
f
# Out:
#  2
# t

# %%
F = sympy.laplace_transform(f, t, s, noconds=True)
F
# Out:
# 2
# ──
#  3
# s

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1M-OJ4J-D4QTAc5jEialGC1Sleg30Xfn9" width="450">

# %%
t, s = sympy.symbols('t, s')
a = sympy.symbols('a', real=True, positive=True)

f = t**3
f
# Out:
#  3
# t

# %%
F = sympy.laplace_transform(f, t, s, noconds=True)
F
# Out:
# 6
# ──
#  4
# s

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1M0QOK2dV615Bop8xHJJW-sIR5phzi9sH" width="450">

# %%
t, s = sympy.symbols('t, s')
e = sympy.Symbol('e')
a = sympy.symbols('a', real=True, positive=True)

f = e**(-3*t)
f
# Out:
#  -3⋅t
# e

# %%
X, a, cond = sympy.laplace_transform(sympy.exp(-3*t), t, s)
X, a, cond
X
# Out:
#   1
# ─────
# s + 3

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1MVzxjsdQtoUg_RdympTnfypBdzXhSf37" width="450">

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1MXbBuLrcaeeo4clp4FObJHn8nAQUTFhg" width="450">

# %%
t, s = sympy.symbols('t, s')
a = sympy.symbols('a', real=True, positive=True)

f = sympy.sin(2*t)
f
# Out:
# sin(2⋅t)

# %%
F = sympy.laplace_transform(f, t, s, noconds=True)
F
# Out:
#   2
# ──────
#  2
# s  + 4

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1LgQt0sGR7Kw5zv6LlKLN0Emlc6SSuQpR" width="450">

# %%
t, s = sympy.symbols('t, s')
a = sympy.symbols('a', real=True, positive=True)

f = 1+5*t
f
# Out:
# 5⋅t + 1

# %%
F = sympy.laplace_transform(f, t, s, noconds=True)
F
# Out:
# s + 5
# ─────
#    2
#   s

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1LFD-8RV_TSY13FmEois_2hnXFS5JSTkx" width="450">

# %%
t, s = sympy.symbols('t, s')
e = sympy.Symbol('e')
a = sympy.symbols('a', real=True, positive=True)

f = 5*e**(-3*t)-2*sympy.sin(2*t)
f
# Out:
#                  -3⋅t
# -2⋅sin(2⋅t) + 5⋅e

# %%
X, a, cond = sympy.laplace_transform(5*sympy.exp(-3*t)-2*sympy.sin(2*t), t, s)
X, a, cond
X
# Out:
#     2
#  5⋅s  - 4⋅s + 8
# ────────────────
#         ⎛ 2    ⎞
# (s + 3)⋅⎝s  + 4⎠

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1LXyX2TAiDVif4Fmls20jLUC19rbBKv-J" width="450">

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1LnKWhy-i1Z02TTRcztF6MptYHAAI1Vte" width="450">

# %%
t, s = sympy.symbols('t, s')
a = sympy.symbols('a', real=True, positive=True)

f = t*sympy.cos(t)
f
# Out:
# t⋅cos(t)

# %%
F = sympy.laplace_transform(f, t, s, noconds=True)
F
# Out:
#      2
#     s  - 1
# ─────────────
#  4      2
# s  + 2⋅s  + 1

# %% [markdown]
# ### Inversa de la Transformada de Laplace
# ##### [[Tabla de contenidos]](#Tabla-de-contenidos) [[Sección II]](#Sección-2:)

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1MiBnkYRvt_87uA0acnEA99UZIhyMhagK" width="450">

# %%
s,t = sympy.symbols('s t')
a = sympy.symbols('a', real=True, positive=True)

Fs = 1/(s**5)
Fs
# Out:
# 1
# ──
#  5
# s

# %%
ft = sympy.inverse_laplace_transform(Fs,s,t)
ft
# Out:
#  4
# t ⋅θ(t)
# ───────
#    24

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1MkTjFllBqfCk2vMTq3JVPFUiB0ftSjIK" width="450">

# %%
s,t = sympy.symbols('s t')
a = sympy.symbols('a', real=True, positive=True)

Fs = 1/((s**2)+7)
Fs
# Out:
#   1
# ──────
#  2
# s  + 7

# %%
ft = sympy.inverse_laplace_transform(Fs,s,t)
ft
# Out:
# √7⋅sin(√7⋅t)⋅θ(t)
# ─────────────────
#         7

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1Mq5ax4M1LDoCiwUSWkwbI13os3rk8ZC0" width="450">

# %%
s,t = sympy.symbols('s t')
a = sympy.symbols('a', real=True, positive=True)

Fs = 1/(s**4)
Fs
# Out:
# 1
# ──
#  4
# s

# %%
ft = sympy.inverse_laplace_transform(Fs,s,t)
ft
# Out:
#  3
# t ⋅θ(t)
# ───────
#    6

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1NBHITlhNwJJWTBi8NjatqTbE8K-XI-l7" width="450">

# %%
s,t = sympy.symbols('s t')
a = sympy.symbols('a', real=True, positive=True)

Fs = 10*s/((s**2)+16)
Fs
# Out:
#   10⋅s
# ───────
#  2
# s  + 16

# %%
ft = sympy.inverse_laplace_transform(Fs,s,t)
ft
# Out:
# 10⋅cos(4⋅t)⋅θ(t)

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1NC_uExeLODoheECQvC2kEBkp_-cri0uZ" width="450">

# %%
s,t = sympy.symbols('s t')
a = sympy.symbols('a', real=True, positive=True)

Fs = s/((s**2)+(2*s)-3)
Fs
# Out:
#      s
# ────────────
#  2
# s  + 2⋅s - 3

# %%
ft = sympy.inverse_laplace_transform(Fs,s,t)
ft
# Out:
# ⎛ 4⋅t    ⎞  -3⋅t
# ⎝ℯ    + 3⎠⋅ℯ    ⋅θ(t)
# ─────────────────────
#           4

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1NPysYerL8vEfJtIuLhM1bQ0A_NzOsCUd" width="450">

# %%
s,t = sympy.symbols('s t')
a = sympy.symbols('a', real=True, positive=True)

Fs = 1/((s**3)+(5*s))
Fs
# Out:
#    1
# ────────
#  3
# s  + 5⋅s

# %%
ft = sympy.inverse_laplace_transform(Fs,s,t)
ft
# Out:
# (1 - cos(√5⋅t))⋅θ(t)
# ────────────────────
#          5

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1NYQbO-efpOzj8WyzhrnWmGqtOPLcmuZ5" width="450">

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1Ng2lGcfkOHb4u8M23kNmtFnTcZn-dcK6" width="450">

# %%
s,t = sympy.symbols('s t')
a = sympy.symbols('a', real=True, positive=True)

Fs = (s+1)/((s**2)+(4*s))
Fs
# Out:
#  s + 1
# ────────
#  2
# s  + 4⋅s

# %%
ft = sympy.inverse_laplace_transform(Fs,s,t)
ft
# Out:
# ⎛ 4⋅t    ⎞  -4⋅t
# ⎝ℯ    + 3⎠⋅ℯ    ⋅θ(t)
# ─────────────────────
#           4

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1NhXODibQR7w23OeTXOl18TtR5QJuW7jy" width="450">

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1NlVDeXlLKfa0CSCOszDKYuwSSH6JyJzK" width="450">

# %%
s,t = sympy.symbols('s t')
a = sympy.symbols('a', real=True, positive=True)

Fs = (2*s+5)/((s-3)**2)
Fs
# Out:
# 2⋅s + 5
# ────────
#        2
# (s - 3)

# %%
ft = sympy.inverse_laplace_transform(Fs,s,t)
ft
# Out:
#             3⋅t
# (11⋅t + 2)⋅ℯ   ⋅θ(t)

# %% [markdown]
# ### Transformada de Laplace Derivada
# ##### [[Tabla de contenidos]](#Tabla-de-contenidos) [[Sección II]](#Sección-2:)

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1OEEwWiYee_f5f0Gr9qsfvjcgQaT3nnfy" width="450">

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1OMa2J_a0hFIM994sKcW965O5PRT47Zgd" width="450">

# %%
t = sympy.symbols("t", positive=True)
y = sympy.Function("y")

s, Y = sympy.symbols("s, Y", real=True)

edo = y(t).diff(t) + 2*y(t)-13*sympy.sin(2*y(t))
sympy.Eq(edo,0)
# Out:
#                           d
# 2⋅y(t) - 13⋅sin(2⋅y(t)) + ──(y(t)) = 0
#                           dt

# %%
L_edo = sympy.laplace_transform(edo, t, s)
sympy.Eq(L_edo,0)
# Out:
# s⋅LaplaceTransform(y(t), t, s) + 2⋅LaplaceTransform(y(t), t, s) - 13⋅LaplaceTr
# ansform(sin(2⋅y(t)), t, s) - y(0) = 0

# %%
def laplace_transform_derivatives(e):
    """
    Evalua las transformadas de Laplace de derivadas de funciones sin evaluar.
    """
    if isinstance(e, sympy.LaplaceTransform):
        if isinstance(e.args[0], sympy.Derivative):
            d, t, s = e.args 
            n = len(d.args) - 1
            return ((s**n) * sympy.LaplaceTransform(d.args[0], t, s) -
                    sum([s**(n-i) * sympy.diff(d.args[0], t, i-1).subs(t, 0)
                         for i in range(1, n+1)]))
        
    if isinstance(e, (sympy.Add, sympy.Mul)):
        t = type(e) 
        return t(*[laplace_transform_derivatives(arg) for arg in e.args])
    
    return e

# %%
L_edo_2 = laplace_transform_derivatives(L_edo)
sympy.Eq(L_edo_2,0)
# Out:
# s⋅LaplaceTransform(y(t), t, s) + 2⋅LaplaceTransform(y(t), t, s) - 13⋅LaplaceTr
# ansform(sin(2⋅y(t)), t, s) - y(0) = 0

# %%
ics = {y(0): 6, y(t).diff(t).subs(t, 0): 0}
ics
# Out:
# ⎧         ⎛d       ⎞│      ⎫
# ⎨y(0): 6, ⎜──(y(t))⎟│   : 0⎬
# ⎩         ⎝dt      ⎠│t=0   ⎭

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1OTrA3n1CQGJXQF-el1HkPvVHVSfbygdc" width="450">

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1OYnGOUqci7iO-Y7ailpHrxMZjhpS_0jp" width="450">

# %%
t = sympy.symbols("t", positive=True)
L = sympy.symbols("L", positive=True)
R = sympy.symbols("R", positive=True)
y = sympy.Function("y")

s, Y = sympy.symbols("s, Y", real=True)

edo = L*y(t).diff(t, t) + R*y(t).diff(t) - y(t) 
sympy.Eq(edo,0)
# Out:
#     2
#    d            d
# L⋅───(y(t)) + R⋅──(y(t)) - y(t) = 0
#     2           dt
#   dt

# %%
s, Y = sympy.symbols("s, Y", real=True)

# %%
L_edo = sympy.laplace_transform(edo, t, s)
sympy.Eq(L_edo, 0)
# Out:
#  2
# s ⋅LaplaceTransform(y(t), t, s) + s⋅LaplaceTransform(y(t), t, s) - s⋅y(0) - La
#
#
#                                     ⎛d       ⎞│
# placeTransform(y(t), t, s) - y(0) - ⎜──(y(t))⎟│    = 0
#                                     ⎝dt      ⎠│t=0

# %%
def laplace_transform_derivatives(e):
    """
    Evalua las transformadas de Laplace de derivadas de funciones sin evaluar.
    """
    if isinstance(e, sympy.LaplaceTransform):
        if isinstance(e.args[0], sympy.Derivative):
            d, t, s = e.args 
            n = len(d.args) - 1
            return ((s**n) * sympy.LaplaceTransform(d.args[0], t, s) -
                    sum([s**(n-i) * sympy.diff(d.args[0], t, i-1).subs(t, 0)
                         for i in range(1, n+1)]))
        
    if isinstance(e, (sympy.Add, sympy.Mul)):
        t = type(e) 
        return t(*[laplace_transform_derivatives(arg) for arg in e.args])
    
    return e

# %%
L_edo_2 = laplace_transform_derivatives(L_edo)
sympy.Eq(L_edo_2,0)
# Out:
#  2
# s ⋅LaplaceTransform(y(t), t, s) + s⋅LaplaceTransform(y(t), t, s) - s⋅y(0) - La
#
#
#                                     ⎛d       ⎞│
# placeTransform(y(t), t, s) - y(0) - ⎜──(y(t))⎟│    = 0
#                                     ⎝dt      ⎠│t=0

# %%
L_edo_3 = L_edo_2.subs(sympy.laplace_transform(y(t), t, s), Y)
sympy.Eq(L_edo_3,0)
# Out:
#    2                             ⎛d       ⎞│
# Y⋅s  + Y⋅s - Y - s⋅y(0) - y(0) - ⎜──(y(t))⎟│    = 0
#                                  ⎝dt      ⎠│t=0

# %%
ics = {y(0): 0, y(t).diff(t).subs(t, 0): 1}
ics
# Out:
# ⎧         ⎛d       ⎞│      ⎫
# ⎨y(0): 0, ⎜──(y(t))⎟│   : 1⎬
# ⎩         ⎝dt      ⎠│t=0   ⎭

# %%
L_edo_4 = L_edo_3.subs(ics)

Y_sol = sympy.solve(L_edo_4, Y)
Y_sol
# Out:
# ⎡    1     ⎤
# ⎢──────────⎥
# ⎢ 2        ⎥
# ⎣s  + s - 1⎦

# %%
y_sol = sympy.inverse_laplace_transform(Y_sol[0], s, t)
y_sol
# Out:
#                 -t⋅(1 + √5)
#                 ────────────
#    ⎛ √5⋅t    ⎞       2
# √5⋅⎝ℯ     - 1⎠⋅ℯ
# ────────────────────────────
#              5

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1OaPQHsCZBbbhmvfY-aPFhLmWVSaSYRO9" width="450">

# %%
t = sympy.symbols("t", positive=True)
y = sympy.Function("y")

# simbolos adicionales.
s, Y = sympy.symbols("s, Y", real=True)

# Defino la ecuación
edo = y(t).diff(t, t) - 3*y(t).diff(t) + 8*y(t)- y(t)**2*sympy.exp(-2*t)
sympy.Eq(edo,0)
# Out:
#                                         2
#    2     -2⋅t              d           d
# - y (t)⋅ℯ     + 8⋅y(t) - 3⋅──(y(t)) + ───(y(t)) = 0
#                            dt           2
#                                       dt

# %%
s, Y = sympy.symbols("s, Y", real=True)

# %%
L_edo = sympy.laplace_transform(edo, t, s)
sympy.Eq(L_edo,0)
# Out:
#  2
# s ⋅LaplaceTransform(y(t), t, s) + s⋅LaplaceTransform(y(t), t, s) - s⋅y(0) - La
#
#
#               ⎛ 2     -2⋅t      ⎞                                           ⎛d
# placeTransform⎝y (t)⋅ℯ    , t, s⎠ + 8⋅LaplaceTransform(y(t), t, s) - y(0) - ⎜─
#                                                                             ⎝d
#
#        ⎞│
# ─(y(t))⎟│    = 0
# t      ⎠│t=0

# %%
def laplace_transform_derivatives(e):
    """
    Evalua las transformadas de Laplace de derivadas de funciones sin evaluar.
    """
    if isinstance(e, sympy.LaplaceTransform):
        if isinstance(e.args[0], sympy.Derivative):
            d, t, s = e.args 
            n = len(d.args) - 1
            return ((s**n) * sympy.LaplaceTransform(d.args[0], t, s) -
                    sum([s**(n-i) * sympy.diff(d.args[0], t, i-1).subs(t, 0)
                         for i in range(1, n+1)]))
        
    if isinstance(e, (sympy.Add, sympy.Mul)):
        t = type(e) 
        return t(*[laplace_transform_derivatives(arg) for arg in e.args])
    
    return e

# %%
L_edo_2 = laplace_transform_derivatives(L_edo)
sympy.Eq(L_edo_2,0)
# Out:
#  2
# s ⋅LaplaceTransform(y(t), t, s) + s⋅LaplaceTransform(y(t), t, s) - s⋅y(0) - La
#
#
#               ⎛ 2     -2⋅t      ⎞                                           ⎛d
# placeTransform⎝y (t)⋅ℯ    , t, s⎠ + 8⋅LaplaceTransform(y(t), t, s) - y(0) - ⎜─
#                                                                             ⎝d
#
#        ⎞│
# ─(y(t))⎟│    = 0
# t      ⎠│t=0

# %%
L_edo_3 = L_edo_2.subs(sympy.laplace_transform(y(t), t, s), Y)
sympy.Eq(L_edo_3,0)
# Out:
#    2                                        ⎛ 2     -2⋅t      ⎞          ⎛d
# Y⋅s  + Y⋅s + 8⋅Y - s⋅y(0) - LaplaceTransform⎝y (t)⋅ℯ    , t, s⎠ - y(0) - ⎜──(y
#                                                                          ⎝dt
#
#     ⎞│
# (t))⎟│    = 0
#     ⎠│t=0

# %%
ics = {y(0): 0, y(t).diff(t).subs(t, 0): -0}
ics
# Out:
# ⎧         ⎛d       ⎞│      ⎫
# ⎨y(0): 0, ⎜──(y(t))⎟│   : 0⎬
# ⎩         ⎝dt      ⎠│t=0   ⎭

# %%
L_edo_4 = L_edo_3.subs(ics)

Y_sol = sympy.solve(L_edo_4, Y)
Y_sol
# Out:
# ⎡                ⎛ 2     -2⋅t      ⎞⎤
# ⎢LaplaceTransform⎝y (t)⋅ℯ    , t, s⎠⎥
# ⎢───────────────────────────────────⎥
# ⎢              2                    ⎥
# ⎣             s  + s + 8            ⎦

# %%
y_sol = sympy.inverse_laplace_transform(Y_sol[0], s, t)
y_sol
# Out:
#                        ⎛                ⎛ 2     -2⋅t      ⎞            ⎞
#                        ⎜LaplaceTransform⎝y (t)⋅ℯ    , t, s⎠            ⎟
# InverseLaplaceTransform⎜───────────────────────────────────, s, t, None⎟
#                        ⎜              2                                ⎟
#                        ⎝             s  + s + 8                        ⎠

# %% [markdown]
# # Referencias
#
# ##### [[Tabla de contenidos]](#Tabla-de-contenidos) [[Sección I]](#Sección-I:) [[Sección II]](#Sección-2:)

# %% [markdown]
# * TRANSFORMADA DE LAPLACE in English Translation. (s. f.). Recuperado 21 de octubre de 2022, de https://tr-ex.me/translation/spanish-english/transformada+de+laplace?t=laplace+transform
#
# * C. Sandrock, «Laplace transforms in SymPy,» Readthedocs, 20 09 2022. [En línea]. Available: https://dynamics-and-control.readthedocs.io/en/latest/1_Dynamics/3_Linear_systems/Laplace%20transforms.html. [Último acceso: 15 10 2022].
#
#
# * J. R. Zapata, «TRANSFORMADA DE LAPLACE,» Github, 31 08 2022. [En línea]. Available: https://github.com/JoseRZapata/SyS/blob/master/Transformada_Laplace.ipynb.
#
# * R. E. L. Briega, «Ecuaciones Diferenciales con Python,» Blog, 10 01 2016. [En línea]. Available: https://relopezbriega.github.io/blog/2016/01/10/ecuaciones-diferenciales-con-python/.
#
# * Transformada de Laplace de una derivada –. (2014, 8 marzo). Ceromascero, una puerta de entrada a las ecuaciones diferenciales. Recuperado 21 de octubre de 2022, de https://ceromascero.wordpress.com/tag/transformada-de-laplace-de-una-derivada/
